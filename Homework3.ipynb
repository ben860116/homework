# %%
Logistic Regression, Naive Bayes, and Clustering
Conceptual, Non-Programming
Naive Bayes

    I have a bucket with 3 red balls and 7 blue balls in it. 
    I reach into the bucket and grab a ball. What is the proability the ball is red, P(R)? The probability that it's blue, P(B)?
P(R)= 3/10 = 0.3
P(B) = 7/10 = 0.7

# %%
Now assume I have two buckets. Bucket 1, B1, have 5 red and 5 blue balls in it. 
Bucket 2, B2, has 2 red and 8 blue balls in it.
I first choose a bucket and then grab a ball.
Assuming I choose bucket 1 and bucket 2 with equal probability,
what is the probability that the chosen ball is red? 
1/2*1/2 + 1/2*2/10 = 0.25+0.1=0.35

blue?
1/2*1/2 + 1/2*8/10 = 0.25+0.25 = 0.5

What is the conditional probability that I choose a red ball given B1, 
P(R|B1)?
P(R|B1)=1/2

# %%
       
    Let's say we're performing a binary classification problem. 
    We're given a binary class label y and a feature vector X with 
    dimensionality m. Meaning there are m features.
        What is Bayes theorem? Write it in terms of X and Y in the way 
        it's used for our classification problem.
         
       P(X|Y)=  P(X) P(Y|X)/P(Y)
        
        In this problem we have 4 probabilities, {P(X), P(Y), P(X|Y), P(Y|X)}, which ones do we need to estimate?
        P(Y|X)

# %% [markdown]
#  What is the Naive Bayes assumption? Why do we need to make this assumption?
#  Naive Bayes classifier assume that the effect of the value of a predictor (x) on a given class (c) is independent of the values of other predictors. This assumption is called class conditional independence.
#     We discussed the following 3 different Naive Bayes implementations in SKLearn. When would you use each?
#         Gaussian?  continuous data, continuous values associatiated with each class are distributed according to a Gaussian distribution.
#         Bernoulli?  Features are independent booleans describig inputs.
#         Multinomial?  With a multinomial event model, samples (feature vectors) represent the frequencies with which certain events have been generated by a multinomial (p_1, \dots, p_n) where p_i is the probability that event i occurs (or K such multinomials in the multiclass case).

# %%
Logistic Regression

    What type of machine learning algorithm is logistic regression? Classification supervised.
    In logistic regression we use the logistic function. What is the logistic function interpretted as?
    f(z) = 1/(1 + e-z)
    What is the assumption of logistic regression? What does the decision boundary look like?
   When our hypothesis (hθ(x)) outputs a number, we treat that value as the estimated probability that y=1 on input x
       When the probability of y being 1 is greater than 0.5 then we can predict y = 1
    Else we predict y = 0
    
    The decision boundary is a property of the hypothesis

    Means we can create the boundary with the hypothesis and parameters without any data

# %%
Clustering

    What type of algorithm is k-means clustering? Supervised or unsupervised?  unsupervised
    Does k-means clustering have any parameters? If so what are they? K , number of clusters 
    What are the assumptions of k-means clustering?
    k-means implicitly assumes that the ordering of the input data set does not matter.
